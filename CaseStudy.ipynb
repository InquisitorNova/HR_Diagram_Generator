# %%
from HR_Diagram_Generator import HR_Diagram_Generator

# %%
Sector_Data = [r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_1.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_2.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_3.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_4.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_5.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_6.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_7.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_8.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_9.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_10.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_11.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_12.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_13.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_27.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_28.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_29.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_30.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_31.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_32.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_33.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_34.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_35.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_36.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_37.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_38.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Southern Ecliptic\Sector_39.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_14.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_15.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_16.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_17.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_18.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_19.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_20.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_21.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_22.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_23.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_24.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_25.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_26.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_40.csv",
r"D:\44730\Documents\Projects\URSS Exoplanet Research\HR-Diagram PositionData\Blog Post\Northern Ecliptic\Sector_41.csv",
]

# %%
Sectors = HR_Diagram_Generator()

# %%
Sectors.add_Sectors_Stars(Sector_Data)

# %%
Sectors.Plot_HR_Diagram_Using_Heatmap(["parallax", "parallax"], "phot_g_mean_mag", "bp_rp", 2300, [-4.0,14.0,2.0], [-1.0,4.0,0.5], False, True, [0,1], 1000, 0)
# Out:
# The original number of stars plotted from the Sectors DataSet is:  2326903
# The percentage of the Sectors DataSet with missing parallax data is 0.753%
# The Color_Range:  [-1.0, 4.0, 0.5]
# The Magnitude_Range:  [-4.0, 14.0, 2.0]
# The percentage of the Sectors DataSet with missing colors is 1.106%
# The percentage of the Sectors DataSet that will be missing from the HR_Diagram is 1.363%
# The shape of the Sectors_Dataset array is (2304317, 2)
# Given your selection of the colour and magnitude range, and cutting out errorous data, the HR Diagram now contains 2228156 Sector stars
# 247 1481 854 1939
# This process took: 142.02269077301025 seconds.
# The filter applied is:  0
# (142.02269077301025, 2300)
