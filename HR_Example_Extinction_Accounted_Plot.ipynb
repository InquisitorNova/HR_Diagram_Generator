# %%
from HR_Diagram_GeneratorExtinction import HR_Diagram_Generator

# %%
Sector_Data = [r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_1.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_2.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_3.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_4.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_5.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_6.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_7.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_8.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_9.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_10.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_11.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_12.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_13.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_27.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_28.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_29.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_30.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_31.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_32.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_33.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_34.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_35.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_36.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_37.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_38.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_39.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_40.csv",
               r"F:\Documents\Projects\URSS Exoplanet Research\New Sector Data\Sector_41.csv"]

# %%
Sectors = HR_Diagram_Generator()

# %%
Sectors.add_Sectors_Stars(Sector_Data)

# %%
Sectors.Plot_HR_Diagram_Using_Heatmap(["distance_gspphot", "distance_gspphot"], "phot_g_mean_mag", "bp_rp", "ag_gspphot", "ebpminrp_gspphot", 1600, [-6.0,6.0,2.0], [-1.0,3.0,0.5], False, True, [0,1], 1000, 0)
# Out:
# The original number of stars plotted from the Sectors DataSet is:  1509203
# The percentage of the Sectors DataSet with missing distances is 17.553%
# The Color_Range:  [-1.0, 3.0, 0.5]
# The Magnitude_Range:  [-6.0, 6.0, 2.0]
# The percentage of the Sectors DataSet with missing colors is 17.553%
# The percentage of the Sectors DataSet that will be missing from the HR_Diagram is 17.553%
# The shape of the Sectors_Dataset array is (1509203, 2)
# Given your selection of the colour and magnitude range, and cutting out errorous data, the HR Diagram now contains 1205430 Sector stars
# 272 1369 584 1434
# This process took: 78.33250141143799 seconds.
# The filter applied is:  0
# (78.33250141143799, 1600)
